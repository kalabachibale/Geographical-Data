# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
railways = gpd.read_file("railways.shp")

# %%
railways.head()
# Out:
#     osm_id                                  name          type  \
# 0  3826037                                  None          rail
# 1  4064202  Apple Express (Avontuur Branch Line)  narrow_gauge
# 2  4238811                                  None          rail
# 3  4247103                                  None          rail
# 4  4251316                                  None          rail
#
#                                             geometry
# 0  LINESTRING (25.9035887 -33.1198681, 25.9006971...
# 1  LINESTRING (25.4614841 -33.9603849, 25.4673505...
# 2  LINESTRING (28.1821566 -25.7557696, 28.1851578...
# 3  LINESTRING (18.4929218 -33.9324557, 18.4931359...
# 4  LINESTRING (28.1944947 -25.7641176, 28.1957822...

# %%
railways.plot()
fig = plt.gcf()
fig.set_size_inches(10, 10)

# %%
places = gpd.read_file("places.shp")

# %%
places.head()
# Out:
#      osm_id          name    type  population                        geometry
# 0  21320910   Newton Park  suburb           0      POINT (25.565 -33.9455556)
# 1  21320911        Walmer  suburb           0  POINT (25.5908333 -33.9783333)
# 2  21320912     Mill Park  suburb           0  POINT (25.5888889 -33.9633333)
# 3  21320913      Linkside  suburb           0  POINT (25.5798899 -33.9636177)
# 4  21489671  Stellenbosch    town           0  POINT (18.8691667 -33.9344444)

# %%
places.plot()
fig = plt.gcf()
fig.set_size_inches(10, 10)

# %%
points = gpd.read_file("points.shp")

# %%
points.head()
# Out:
#      osm_id  name             type                        geometry
# 0  18405781  None  traffic_signals  POINT (25.5743126 -33.9513302)
# 1  18405795  None  traffic_signals  POINT (25.5650499 -33.9487488)
# 2  18405800  None  traffic_signals  POINT (25.5618406 -33.9482766)
# 3  18405810  None  traffic_signals  POINT (25.5713304 -33.9501558)
# 4  18405868  None  traffic_signals  POINT (25.5801986 -33.9532699)

# %%
points.plot()
fig = plt.gcf()
fig.set_size_inches(10, 10)

# %%
roads = gpd.read_file("roads.shp")

# %%
roads.head()
# Out:
#     osm_id           name   ref          type  oneway  maxspeed  \
# 0  3715718   Lucas Street  None   residential       0         0
# 1  3715888      Ring Road  None  unclassified       1         0
# 2  3823543  Hudson Street  None   residential       0         0
# 3  3823545     6th Avenue  None  unclassified       0         0
# 4  3823547     5th Avenue  None  unclassified       0         0
#
#                                             geometry
# 0  LINESTRING (25.5575288 -33.9511076, 25.5606532...
# 1  LINESTRING (25.5759182 -33.9486899, 25.5761347...
# 2  LINESTRING (25.5578192 -33.9502239, 25.5609366...
# 3  LINESTRING (25.5568571 -33.9534911, 25.556778 ...
# 4  LINESTRING (25.5598047 -33.9539491, 25.5599718...

# %%
roads.plot()
fig = plt.gcf()
fig.set_size_inches(10, 10)

# %%
waterways = gpd.read_file("waterways.shp")

# %%
waterways.head()
# Out:
#     osm_id               name    type  width  \
# 0  4245047  Elsieskraal River   drain      0
# 1  4268306               None  stream      0
# 2  4270471               None   river      0
# 3  4275572               None   drain      0
# 4  4275573               None   drain      0
#
#                                             geometry
# 0  LINESTRING (18.5216808 -33.9280761, 18.521372 ...
# 1  LINESTRING (28.2795663 -25.77639, 28.2802291 -...
# 2  LINESTRING (28.4166193 -25.8830934, 28.4174132...
# 3  LINESTRING (18.4711452 -33.9798561, 18.4713488...
# 4  LINESTRING (18.4696965 -33.9832388, 18.4697385...

# %%
waterways.plot()
fig = plt.gcf()
fig.set_size_inches(10, 10)
