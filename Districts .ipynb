# %%
import pandas as pd
import geopandas as gdp 
from matplotlib.pyplot import figure

# %% [markdown]
# ***Find data published by Ghana's national and local government,
# and public bodies to help you understand what we do, and build products and services***

# %%
Districts = gdp.read_file("Desktop/Ghana_Districts_170.json")
Districts.head()
# Out:
#           REGION     DISTRICT  ID1 DIST_CODE          AREA     PERIMETER  \
# 0  GREATER ACCRA       ADENTA    0      0305  8.389607e+08  167547.37152
# 1  GREATER ACCRA     GA SOUTH  715      0301  3.947833e+09  409293.46622
# 2  GREATER ACCRA  DANGBE WEST  743      0309  1.712051e+10  595545.41431
# 3  GREATER ACCRA        A M A    0      0304  1.906550e+09  205324.16994
# 4  GREATER ACCRA      GA EAST  713      0303  1.650036e+09  258412.98309
#
#       AREA_KM                                           geometry
# 0    77.94197  MULTIPOLYGON (((1227875.228 368213.512, 122770...
# 1   366.76557  POLYGON ((1116038.000 290630.215, 1115779.001 ...
# 2  1590.54715  POLYGON ((1388013.000 466480.213, 1386701.000 ...
# 3   177.12421  POLYGON ((1177724.167 347581.219, 1177986.285 ...
# 4   153.29333  POLYGON ((1207596.180 418470.158, 1208322.565 ...

# %%
Districts.DISTRICT.unique()
# Out:
# array(['ADENTA', 'GA SOUTH', 'DANGBE WEST', 'A M A', 'GA EAST',
#        'ASHAIMAN', 'LEDZOKUKU / KROWOR', 'TEMA', 'ZABZUGU TATALI',
#        'CHEREPONI', 'WEST GONJA', 'YENDI', 'TAMALE METRO',
#        'TOLON KUMBUGU', 'WA MUNICIPAL', 'LAWRA', 'JIRAPA',
#        'SISSALA  WEST', 'LAMBUSSIE KARNI', 'NADOWLI', 'BAWKU MUNICIPAL',
#        'BOLGATANGA MUNICIPAL', 'BONGO', 'KASENA NANKANA WEST', 'WA WEST',
#        'SAWLA/TUNA/KALBA', 'SISSALA EAST', 'BUILSA',
#        'KASENA NANKANA EAST', 'TALENSI NABDAM', 'BUNKPURUGU YONYO',
#        'GARU TEMPANE', 'MAMPRUSI EAST', 'BAWKU WEST', 'DORMAA EAST',
#        'BEREKUM', 'JAMAN NORTH', 'JAMAN SOUTH', 'SUNYANI WEST',
#        'ASUNAFO NORTH', 'NKORANZA NORTH', 'ASUTIFI', 'KINTAMPO SOUTH',
#        'TANO NORTH', 'KETU NORTH', 'KETU SOUTH', 'KETA MUNICIPAL',
#        'KADJEBI', 'NORTH TONGU', 'SOUTH TONGU', 'AKATSI', 'HOHOE',
#        'JASIKAN', 'KRACHI EAST', 'NKWANTA SOUTH', 'AFIGYA KWABRE',
# ...

# %%
Districts.plot(figsize=(15, 15))

# %%
ADENTA = Districts.loc[Districts['DISTRICT'] == 'ADENTA']

# %%
ADENTA.plot(figsize=(10, 10))

# %%
SENE = Districts.loc[Districts['DISTRICT'] == 'SENE']

# %%
SENE.plot(figsize=(10, 10))

# %%
JIRAPA = Districts.loc[Districts['DISTRICT'] == 'JIRAPA']

# %%
JIRAPA.plot(figsize=(9, 9))

# %%
GUSHIEGU = Districts.loc[Districts['DISTRICT'] == 'GUSHIEGU']

# %%
GUSHIEGU.plot(figsize=(10, 10))
